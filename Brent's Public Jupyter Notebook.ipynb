# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Brent Carcamo__<br>
# Data Scientist

# %% [markdown]
# _I am interested in data science because I am interested in solving valuable problems for large organizations._

# %% [markdown]
# ### My code below multiplies the number 2 by 3.

# %%
(2)*(3)

# %% [markdown]
#  - Hello there.
#       - This is my example of a bulleted list.
#       - I thought it was pretty neat.
#
# 1. Hello there.
# 2. This is my example of a numbered list.
# 3. My numbered list ends here.
#
# <a href="https://organicfeeds.com/wp-content/uploads/2021/03/How-To-Raise-A-Baby-Duck-scaled-1.jpg" target="_blank" rel="noopener noreferrer">Ducky photo</a>
