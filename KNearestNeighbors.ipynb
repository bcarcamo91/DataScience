# %%
#Load required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing
# %matplotlib inline

#Import relevant data set
df = pd.read_csv('sampledataset.csv')

#(Optional) Understanding how many of each class is in the dataset
df['custcat'].value_counts()

#(Optional) Variable exploratory analysis
df.hist(column='income', bins=50)

#K-Nearest Neighbors
#Create x and y numpy arrays based on the dependent and independent variables
x = df[['region', 'tenure', 'age']].values
y = df[['custcat']].values #cust cat is the dependent variable

#Split the data into testing and training
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

#Standardize the data using the preporcessing standard scaler
x_train_norm = preprocessing.StandardScaler().fit(x_train).transform(x_train.astype(float))
x_test_norm = preprocessing.StandardScaler().fit(x_test).transform(x.test.astype(float))

#Implement k-nearest neighbors
from sklearn.neighbors import KNeighborsClassifier

#Training the model and picking k
k=4
neigh_model = KNeighborsClassifier(n_neighbors = k).fit(x_train_norm, y_train)
neigh_model

#Predicting with the model
yhat = neigh_model.predict(x_test_norm)

#Accuracy evaluation
#Accuracy classification score = jaccard score function. It calculates
#how close the actual labels and predicted labels are matched in the test set
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh_model.predict(x_train_norm)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))


#You can use a for loop to calculate the accuracy of KNN for different
#values of k
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))

for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train_norm,y_train)
    yhat=neigh.predict(X_test_norm)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
